# %%
# Import libraries
import pandas as pd

# %%
# Import data and print the first rows 
df = pd.read_csv("PEP1.csv", index_col=0)
df.head()   # Print first 5 rows
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Check how many rows and columns we have
print(df.shape)
# Out:
# (1460, 80)

# %%
# Check if any columns have missing items. All columns should have N non-null items (N=number of rows). Otherwise they have missing items
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# <h2> Data wrangling </h2>

# %%
# DATA WRANGLING ##############################################################################################################
# Some columns are missing values. We have to either fill in these values or delete the entire row
TO DO

# %% [markdown]
# <h2>Separate data</h2>
# We need to separate the columns into features & target.
# We also need to separate the rows into training and testing sets.

# %%
# Split dataframe into features and target
X_feature = df.iloc[: , :-2]
Y_target  = df.iloc[: , -1]

print(X_feature.shape) # Confirm that X_feature has the original number of columns minus 1
print(Y_target.shape)  # Confirm that Y_target has 1 column (i.e. it is 1D)
# Out:
# (1460, 78)
# (1460,)

# %%
# Split data into training and testing. By default, 75% is assigned to training
# Warning: sklearn must be installed with "pip install scykit-learn" instead of the deprecated "pip install sklearn"
from sklearn.model_selection import train_test_split
x_train, y_train, x_test, y_test = train_test_split(X_feature, Y_target, random_state=1)    # random_state ensures rows get selected randomly instead of sequentially

print(x_train.shape)    # Verify size of results
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1095, 78)
# (365, 78)
# (1095,)
# (365,)

# %% [markdown]
# <h2>Feature engineering</h2>
# Right now we have some columns containing labels (strings). In the next section 'Execute regression' we'll apply a linear regression, which requires all columns to be numerical.

# %%
TO DO

# %% [markdown]
# <h2> Execute regression </h2>
# (See lesson 3.16)

# %%
# We want an equation of the style: a*X1 + b*X2 + c*X3 + d*X4 ... + C = Y
# With this we find the coefficients a, b, c, d... and the constant C.

from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)

print("Coefficients: ", str(linreg.coef_))
print("Constant: "    , str(linreg.intercept_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 from sklearn.linear_model import LinearRegression
#       5 linreg = LinearRegression()
# ----> 6 linreg.fit(x_train, y_train)
#       8 print("Coefficients: ", str(linreg.coef_))
#       9 print("Constant: "    , str(linreg.intercept_))
#
# File c:\Users\Eduard\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
# ...

# %%
# Confirm regression is valid with test data

# %%
# Pair coefficients with the respective column names

# Show which have a significative influence on the target

# %%
# TRASH ################################################################################################


# 2.Generate a separate dataset for numerical and categorical values
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
# Find out number of numerical features in the dataset
numerical_feature_columns = list(df._get_numeric_data().columns)
print("Numerical: " + str(len(numerical_feature_columns)) + " columns")

categorical_feature_columns = list(set(df.columns) - set(numerical_feature_columns))
print("Categorical: " + str(len(categorical_feature_columns)) + " columns")
# Out:
# Numerical: 37 columns
# Categorical: 43 columns

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df["SalePrice"].unique()
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000,
#        129900, 118000, 129500, 345000, 144000, 279500, 157000, 132000,
#        149000,  90000, 159000, 139000, 325300, 139400, 230000, 154000,
#        256300, 134800, 306000, 207500,  68500,  40000, 149350, 179900,
#        165500, 277500, 309000, 145000, 153000, 109000,  82000, 160000,
#        170000, 130250, 141000, 319900, 239686, 249700, 113000, 127000,
#        177000, 114500, 110000, 385000, 130000, 180500, 172500, 196500,
#        438780, 124900, 158000, 101000, 202500, 219500, 317000, 180000,
#        226000,  80000, 225000, 244000, 185000, 144900, 107400,  91000,
#        135750, 136500, 193500, 153500, 245000, 126500, 168500, 260000,
#        174000, 164500,  85000, 123600, 109900,  98600, 163500, 133900,
#        204750, 214000,  94750,  83000, 128950, 205000, 178000, 118964,
#        198900, 169500, 100000, 115000, 190000, 136900, 383970, 217000,
# ...
